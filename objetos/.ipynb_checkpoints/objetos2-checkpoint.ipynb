# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tigarto/TdeA/blob/master/objetos/objetos2.ipynb)

# %%
# !pip3 install tutormagic
# %load_ext tutormagic
# Out:
# Collecting tutormagic
#   Using cached https://files.pythonhosted.org/packages/26/4c/170e56dce3ecbf0608f37b3b99100bd2666cac181da14bc685516e958435/tutormagic-0.3.0-py2.py3-none-any.whl
# Collecting notebook>=3.0 (from tutormagic)
#   Using cached https://files.pythonhosted.org/packages/b1/f1/0a67f09ef53a342403ffa66646ee39273e0ac79ffa5de5dbe2f3e28b5bdf/notebook-6.0.3-py3-none-any.whl
# Collecting terminado>=0.8.1 (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/ff/96/1d9a2c23990aea8f8e0b5c3b6627d03196a73771a17a2d9860bbe9823ab6/terminado-0.8.3-py2.py3-none-any.whl
# Collecting jupyter-client>=5.3.4 (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/40/75/4c4eb43749e59db3c1c7932b50eaf8c4b8219b1b5644fe379ea796f8dbe5/jupyter_client-6.0.0-py3-none-any.whl
# Collecting Send2Trash (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting nbconvert (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/79/6c/05a569e9f703d18aacb89b7ad6075b404e8a4afde2c26b73ca77bb644b14/nbconvert-5.6.1-py2.py3-none-any.whl
# Collecting prometheus-client (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/b3/23/41a5a24b502d35a4ad50a5bb7202a5e1d9a0364d0c12f56db3dbf7aca76d/prometheus_client-0.7.1.tar.gz
# Collecting jupyter-core>=4.6.1 (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/63/0d/df2d17cdf389cea83e2efa9a4d32f7d527ba78667e0153a8e676e957b2f7/jupyter_core-4.6.3-py2.py3-none-any.whl
# Collecting pyzmq>=17 (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/41/fa/e6e10410f01b03d10ab0705717d1246f63cdbbc0676140c78f0f757db332/pyzmq-19.0.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting traitlets>=4.2.1 (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/ca/ab/872a23e29cec3cf2594af7e857f18b687ad21039c1f9b922fac5b9b142d5/traitlets-4.3.3-py2.py3-none-any.whl
# Collecting nbformat (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/ac/eb/de575b7a64e7ab8d8c95e4c180ccc36deda3f1379186c4ee7adf6c2f1586/nbformat-5.0.4-py3-none-any.whl
# Collecting tornado>=5.0 (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz
# Collecting ipython-genutils (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting ipykernel (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/d7/62/d1a5d654b7a21bd3eb99be1b59a608cc18a7a08ed88495457a87c40a0495/ipykernel-5.1.4-py3-none-any.whl
# Collecting jinja2 (from notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/27/24/4f35961e5c669e96f6559760042a55b9bcfcdb82b9bdb3c8753dbe042e35/Jinja2-2.11.1-py2.py3-none-any.whl
# Collecting ptyprocess; os_name != "nt" (from terminado>=0.8.1->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting python-dateutil>=2.1 (from jupyter-client>=5.3.4->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting entrypoints>=0.2.2 (from nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting pygments (from nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/2d/68/106af3ae51daf807e9cdcba6a90e518954eb8b70341cee52995540a53ead/Pygments-2.6.1-py3-none-any.whl
# Collecting defusedxml (from nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting bleach (from nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/6e/87/f88b0e33914420fe11fe8b820c10d045a342c2a015e79ad8309de4bba820/bleach-3.1.1-py2.py3-none-any.whl
# Collecting testpath (from nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/1b/9e/1a170feaa54f22aeb5a5d16c9015e82234275a3c8ab630b552493f9cb8a9/testpath-0.4.4-py2.py3-none-any.whl
# Collecting pandocfilters>=1.4.1 (from nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting mistune<2,>=0.8.1 (from nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting decorator (from traitlets>=4.2.1->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl
# Collecting six (from traitlets>=4.2.1->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting jsonschema!=2.5.0,>=2.4 (from nbformat->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl
# Collecting ipython>=5.0.0 (from ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/61/6f/69f1eec859ce48a86660529b166b6ea466f0f4ab98e4fc0807b835aa22c6/ipython-7.13.0-py3-none-any.whl
# Collecting MarkupSafe>=0.23 (from jinja2->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting webencodings (from bleach->nbconvert->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting attrs>=17.4.0 (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting setuptools (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/70/b8/b23170ddda9f07c3444d49accde49f2b92f97bb2f2ebc312618ef12e4bd6/setuptools-46.0.0-py3-none-any.whl
# Collecting importlib-metadata; python_version < "3.8" (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/8b/03/a00d504808808912751e64ccf414be53c29cad620e3de2421135fcae3025/importlib_metadata-1.5.0-py2.py3-none-any.whl
# Collecting pyrsistent>=0.14.0 (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/90/aa/cdcf7ef88cc0f831b6f14c8c57318824c9de9913fe8de38e46a98c069a35/pyrsistent-0.15.7.tar.gz
# Collecting pickleshare (from ipython>=5.0.0->ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting backcall (from ipython>=5.0.0->ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz
# Collecting pexpect; sys_platform != "win32" (from ipython>=5.0.0->ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/39/7b/88dbb785881c28a102619d46423cb853b46dbccc70d3ac362d99773a78ce/pexpect-4.8.0-py2.py3-none-any.whl
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 (from ipython>=5.0.0->ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/ab/29/d744cee89937b7e52a5c20ca237a6c77298f757965eb3eb0c653df1bfb14/prompt_toolkit-3.0.4-py3-none-any.whl
# Collecting jedi>=0.10 (from ipython>=5.0.0->ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/01/67/333e2196b70840f411fd819407b4e98aa3150c2bd24c52154a451f912ef2/jedi-0.16.0-py2.py3-none-any.whl
# Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Collecting wcwidth (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/58/b4/4850a0ccc6f567cc0ebe7060d20ffd4258b8210efadc259da62dc6ed9c65/wcwidth-0.1.8-py2.py3-none-any.whl
# Collecting parso>=0.5.2 (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=3.0->tutormagic)
#   Using cached https://files.pythonhosted.org/packages/da/15/888f80e429a971d3838124adde705d7b07650aa3a59f4db07d61f653b8cd/parso-0.6.2-py2.py3-none-any.whl
# Building wheels for collected packages: prometheus-client, tornado, pandocfilters, pyrsistent, backcall
#   Running setup.py bdist_wheel for prometheus-client ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-fg7dsl87/prometheus-client/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpq5sp8wfepip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for prometheus-client
#   Running setup.py clean for prometheus-client
#   Running setup.py bdist_wheel for tornado ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-fg7dsl87/tornado/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmp9k2bdtg1pip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for tornado
#   Running setup.py clean for tornado
#   Running setup.py bdist_wheel for pandocfilters ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-fg7dsl87/pandocfilters/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpxwpcx3txpip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for pandocfilters
#   Running setup.py clean for pandocfilters
#   Running setup.py bdist_wheel for pyrsistent ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-fg7dsl87/pyrsistent/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmp5ys46i22pip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for pyrsistent
#   Running setup.py clean for pyrsistent
#   Running setup.py bdist_wheel for backcall ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-fg7dsl87/backcall/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmp0dc6855tpip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for backcall
#   Running setup.py clean for backcall
# Failed to build prometheus-client tornado pandocfilters pyrsistent backcall
# Installing collected packages: ptyprocess, tornado, terminado, pyzmq, decorator, six, ipython-genutils, traitlets, jupyter-core, python-dateutil, jupyter-client, Send2Trash, attrs, setuptools, zipp, importlib-metadata, pyrsistent, jsonschema, nbformat, entrypoints, pygments, defusedxml, webencodings, bleach, testpath, pandocfilters, MarkupSafe, jinja2, mistune, nbconvert, prometheus-client, pickleshare, backcall, pexpect, wcwidth, prompt-toolkit, parso, jedi, ipython, ipykernel, notebook, tutormagic
#   Running setup.py install for tornado ... done
#   Running setup.py install for pyrsistent ... done
#   Running setup.py install for pandocfilters ... done
#   Running setup.py install for prometheus-client ... done
#   Running setup.py install for backcall ... done
# Successfully installed MarkupSafe-1.1.1 Send2Trash-1.5.0 attrs-19.3.0 backcall-0.1.0 bleach-3.1.1 decorator-4.4.2 defusedxml-0.6.0 entrypoints-0.3 importlib-metadata-1.5.0 ipykernel-5.1.4 ipython-7.13.0 ipython-genutils-0.2.0 jedi-0.16.0 jinja2-2.11.1 jsonschema-3.2.0 jupyter-client-6.0.0 jupyter-core-4.6.3 mistune-0.8.4 nbconvert-5.6.1 nbformat-5.0.4 notebook-6.0.3 pandocfilters-1.4.2 parso-0.6.2 pexpect-4.8.0 pickleshare-0.7.5 prometheus-client-0.7.1 prompt-toolkit-3.0.4 ptyprocess-0.6.0 pygments-2.6.1 pyrsistent-0.15.7 python-dateutil-2.8.1 pyzmq-19.0.0 setuptools-46.0.0 six-1.14.0 terminado-0.8.3 testpath-0.4.4 tornado-6.0.4 traitlets-4.3.3 tutormagic-0.3.0 wcwidth-0.1.8 webencodings-0.5.1 zipp-3.1.0

# %% [markdown]
# ## Clases y objetos ##

# %% [markdown]
# **Ejemplo**: Hacer una clase que modele un punto 2D.
#
# La siguiente grafica muestra la forma general de unaaa clase punto.
#
# ![plano_cartesiano](plano_cartesiano.jpeg)
#
# A continuación se muestra el codigo asociado a esta clase:
#
# ```java
# class Punto {
#
#     private double x;
#     private double y;
#
#     public Punto() {
#         x = 0;
#         y = 0;
#     }
#
#     public double getX() {
#         return x;
#     }
#
#     public void setX(double x) {
#         this.x = x;
#     }
#
#     public double getY() {
#         return y;
#     }
#
#     public void setY(double y) {
#         this.y = y;
#     }
#
#     public void setXY(double x, double y) {
#         this.x = x;
#         this.y = y;
#     }
#
#     public Punto(double x, double y) {
#         this.x = x;
#         this.y = y;
#     }
#
#     public void imprimirCoordenadas() {
#         System.out.println("(" + x + ", " + y +")");
#
#     }
#
#     public double calcularDistancia(double x, double y) {
#         double d;
#         d = Math.sqrt(Math.pow(this.x - x, 2) +
#                       Math.pow(this.y - y, 2));
#         return d;
#     }
#
#     public double calcularDistancia(Punto p) {
#         double d;
#         d = Math.sqrt(Math.pow(this.x - p.x, 2) +
#                       Math.pow(this.y - p.y, 2));
#         return d;
#     }
#
# }
# ```
#
# Para probar la clase Punto vamos a proceder a instanciar objetos tipo punto para modelar la grafica que se muestra a continuacion:
#
# ![tres_puntos](tres_puntos.png)
#
# En el siguiente [enlace](https://repl.it/@HENRYALBERTOALB/ejemploPunto) se puede llevar a cabo la ejecución del código anterior. Si lo que se desea es hacer un analisis mas exaustivo, puede correr el siguiente codigo en pythontutor.

# %%
# %%tutor -l java -k
#
# class Punto {
#
#     private double x;
#     private double y;
#
#     public Punto() {
#         x = 0;
#         y = 0;
#     }
#
#     public double getX() {
#         return x;
#     }
#
#     public void setX(double x) {
#         this.x = x;
#     }
#
#     public double getY() {
#         return y;
#     }
#
#     public void setY(double y) {
#         this.y = y;
#     }
#
#     public void setXY(double x, double y) {
#         this.x = x;
#         this.y = y;
#     }
#
#     public Punto(double x, double y) {
#         this.x = x;
#         this.y = y;
#     }
#
#     public void imprimirCoordenadas() {
#         System.out.println("(" + x + ", " + y +")");
#
#     }
#
#     public double calcularDistancia(double x, double y) {
#         double d;
#         d = Math.sqrt(Math.pow(this.x - x, 2) +
#                       Math.pow(this.y - y, 2));
#         return d;
#     }
#
#     public double calcularDistancia(Punto p) {
#         double d;
#         d = Math.sqrt(Math.pow(this.x - p.x, 2) +
#                       Math.pow(this.y - p.y, 2));
#         return d;
#     }
#
# }
#
# public class PointDemo {
#     public static void main(String[] args) {
#         /* Creando 4 objetos tipo punto */
#         Punto O = new Punto();
#         Punto A = new Punto(2,3);
#         Punto B = new Punto(-3,1);
#         Punto C = new Punto(-1.5,-2.5);
#
#         /* Imprimiendo las coordenadas */
#         System.out.print("O: ");
#         O.imprimirCoordenadas();
#         System.out.print("A: ");
#         A.imprimirCoordenadas();
#         System.out.print("B: ");
#         B.imprimirCoordenadas();
#         System.out.print("C: ");
#         C.imprimirCoordenadas();
#
#         /* Imprimiendo distancias */
#         // Distancia entre A y B
#         double d_AB = A.calcularDistancia(B.getX(),B.getY());
#         System.out.println("Distancia (A,B): " + d_AB);
#         // Distancia entre B y C
#         double d_BC;
#         d_BC = B.calcularDistancia(C);
#         System.out.println("Distancia (B,C): " + d_BC);
#     }
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%0Aclass%20Punto%20%7B%0A%20%20%20%0A%20%20%20%20private%20double%20x%3B%0A%20%20%20%20private%20double%20y%3B%0A%0A%20%20%20%20public%20Punto%28%29%20%7B%0A%20%20%20%20%20%20%20%20x%20%3D%200%3B%0A%20%20%20%20%20%20%20%20y%20%3D%200%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20double%20getX%28%29%20%7B%0A%20%20%20%20%20%20%20%20return%20x%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20void%20setX%28double%20x%29%20%7B%0A%20%20%20%20%20%20%20%20this.x%20%3D%20x%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20double%20getY%28%29%20%7B%0A%20%20%20%20%20%20%20%20return%20y%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20void%20setY%28double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20this.y%20%3D%20y%3B%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20void%20setXY%28double%20x%2C%20double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20this.x%20%3D%20x%3B%0A%20%20%20%20%20%20%20%20this.y%20%3D%20y%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20Punto%28double%20x%2C%20double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20this.x%20%3D%20x%3B%0A%20%20%20%20%20%20%20%20this.y%20%3D%20y%3B%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20void%20imprimirCoordenadas%28%29%20%7B%0A%20%20%20%20%20%20%20%20System.out.println%28%22%28%22%20%2B%20x%20%2B%20%22%2C%20%22%20%2B%20y%20%2B%22%29%22%29%3B%0A%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20double%20calcularDistancia%28double%20x%2C%20double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20double%20d%3B%0A%20%20%20%20%20%20%20%20d%20%3D%20Math.sqrt%28Math.pow%28this.x%20-%20x%2C%202%29%20%2B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20Math.pow%28this.y%20-%20y%2C%202%29%29%3B%0A%20%20%20%20%20%20%20%20return%20d%3B%20%20%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20double%20calcularDistancia%28Punto%20p%29%20%7B%0A%20%20%20%20%20%20%20%20double%20d%3B%0A%20%20%20%20%20%20%20%20d%20%3D%20Math.sqrt%28Math.pow%28this.x%20-%20p.x%2C%202%29%20%2B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20Math.pow%28this.y%20-%20p.y%2C%202%29%29%3B%0A%20%20%20%20%20%20%20%20return%20d%3B%0A%20%20%20%20%7D%0A%20%20%20%0A%7D%0A%0Apublic%20class%20PointDemo%20%7B%0A%20%20%20%20public%20static%20void%20main%28String%5B%5D%20args%29%20%7B%0A%20%20%20%20%20%20%20%20/%2A%20Creando%204%20objetos%20tipo%20punto%20%2A/%0A%20%20%20%20%20%20%20%20Punto%20O%20%3D%20new%20Punto%28%29%3B%0A%20%20%20%20%20%20%20%20Punto%20A%20%3D%20new%20Punto%282%2C3%29%3B%0A%20%20%20%20%20%20%20%20Punto%20B%20%3D%20new%20Punto%28-3%2C1%29%3B%0A%20%20%20%20%20%20%20%20Punto%20C%20%3D%20new%20Punto%28-1.5%2C-2.5%29%3B%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20/%2A%20Imprimiendo%20las%20coordenadas%20%2A/%0A%20%20%20%20%20%20%20%20System.out.print%28%22O%3A%20%22%29%3B%0A%20%20%20%20%20%20%20%20O.imprimirCoordenadas%28%29%3B%0A%20%20%20%20%20%20%20%20System.out.print%28%22A%3A%20%22%29%3B%0A%20%20%20%20%20%20%20%20A.imprimirCoordenadas%28%29%3B%0A%20%20%20%20%20%20%20%20System.out.print%28%22B%3A%20%22%29%3B%0A%20%20%20%20%20%20%20%20B.imprimirCoordenadas%28%29%3B%0A%20%20%20%20%20%20%20%20System.out.print%28%22C%3A%20%22%29%3B%0A%20%20%20%20%20%20%20%20C.imprimirCoordenadas%28%29%3B%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20/%2A%20Imprimiendo%20distancias%20%2A/%0A%20%20%20%20%20%20%20%20//%20Distancia%20entre%20A%20y%20B%0A%20%20%20%20%20%20%20%20double%20d_AB%20%3D%20A.calcularDistancia%28B.getX%28%29%2CB.getY%28%29%29%3B%0A%20%20%20%20%20%20%20%20System.out.println%28%22Distancia%20%28A%2CB%29%3A%20%22%20%2B%20d_AB%29%3B%0A%20%20%20%20%20%20%20%20//%20Distancia%20entre%20B%20y%20C%0A%20%20%20%20%20%20%20%20double%20d_BC%3B%0A%20%20%20%20%20%20%20%20d_BC%20%3D%20B.calcularDistancia%28C%29%3B%0A%20%20%20%20%20%20%20%20System.out.println%28%22Distancia%20%28B%2CC%29%3A%20%22%20%2B%20d_BC%29%3B%0A%20%20%20%20 ...

# %% [markdown]
# ## Array de objetos ##
# Es posble crear arreglos de objetos que son instancias de las clases que ha sido escrita. La siguiente forma muestra la sintaxis empleada para declarar un arra de objetos:
#
# ```java
# nombreClase []nombreArray = new nombreClase[sizeArray];
# ```
#
# Cuando un array de Objetos es instanciado, cada elemento del arreglo es inicializado a **null**. **null** es un valor especial que indica que los elementos del array aun no han sido referenciados con objetos. Para hacer que cada referenciar cada elemento es necesario clear objetos indiviualmente tal y como se muestra a continuación:
#
# ```java
# nombreArray[0] = new nombreClase(parametros,...);
# nombreArray[1] = new nombreClase(parametros,...);
# ...
# nombreArray[i] = new nombreClase(parametros,...);
# ...
# nombreArray[N] = new nombreClase(parametros,...);
# ```
#
# **Ejemplo**: Crear un arreglo de 4 puntos con las siguientes coordenadas: A(2,1), B(-3,4), C(5,-6), D(-7,-8).
#
# En el siguiente [enlace](https://repl.it/@HENRYALBERTOALB/ejemploVectorPuntos) se puede ejecutar online el código solución al problema (el cual se muestra a continuación tambien).

# %%
# %%tutor -l java -k
#
# class Punto {
#
#     private double x;
#     private double y;
#
#     public Punto() {
#         x = 0;
#         y = 0;
#     }
#
#     public double getX() {
#         return x;
#     }
#
#     public void setX(double x) {
#         this.x = x;
#     }
#
#     public double getY() {
#         return y;
#     }
#
#     public void setY(double y) {
#         this.y = y;
#     }
#
#     public void setXY(double x, double y) {
#         this.x = x;
#         this.y = y;
#     }
#
#     public Punto(double x, double y) {
#         this.x = x;
#         this.y = y;
#     }
#
#     public void imprimirCoordenadas() {
#         System.out.println("(" + x + ", " + y +")");
#
#     }
#
#     public double calcularDistancia(double x, double y) {
#         double d;
#         d = Math.sqrt(Math.pow(this.x - x, 2) +
#                       Math.pow(this.y - y, 2));
#         return d;
#     }
#
#     public double calcularDistancia(Punto p) {
#         double d;
#         d = Math.sqrt(Math.pow(this.x - p.x, 2) +
#                       Math.pow(this.y - p.y, 2));
#         return d;
#     }
#
# }
#
# public class PointDemo2 {
#     public static void main(String[] args) {
#         /* Creando 4 objetos tipo punto */
#         final int NUMPUNTOS = 4;
#         Punto[] puntos;
#         puntos = new Punto[NUMPUNTOS];
#         Punto A = new Punto(2,1);
#         Punto B = new Punto(-3,4);
#         puntos[0] = A;
#         puntos[1] = B;
#         puntos[2] = new Punto(5,-6);
#         puntos[3] = new Punto(-7,-8);
#         imprimirArray(puntos);
#
#     }
#
#     public static void imprimirArray(Punto []v) {
#         for(Punto e: v) {
#             e.imprimirCoordenadas();
#         }
#     }
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%0Aclass%20Punto%20%7B%0A%20%20%20%0A%20%20%20%20private%20double%20x%3B%0A%20%20%20%20private%20double%20y%3B%0A%0A%20%20%20%20public%20Punto%28%29%20%7B%0A%20%20%20%20%20%20%20%20x%20%3D%200%3B%0A%20%20%20%20%20%20%20%20y%20%3D%200%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20double%20getX%28%29%20%7B%0A%20%20%20%20%20%20%20%20return%20x%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20void%20setX%28double%20x%29%20%7B%0A%20%20%20%20%20%20%20%20this.x%20%3D%20x%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20double%20getY%28%29%20%7B%0A%20%20%20%20%20%20%20%20return%20y%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20void%20setY%28double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20this.y%20%3D%20y%3B%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20void%20setXY%28double%20x%2C%20double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20this.x%20%3D%20x%3B%0A%20%20%20%20%20%20%20%20this.y%20%3D%20y%3B%0A%20%20%20%20%7D%0A%0A%20%20%20%20public%20Punto%28double%20x%2C%20double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20this.x%20%3D%20x%3B%0A%20%20%20%20%20%20%20%20this.y%20%3D%20y%3B%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20void%20imprimirCoordenadas%28%29%20%7B%0A%20%20%20%20%20%20%20%20System.out.println%28%22%28%22%20%2B%20x%20%2B%20%22%2C%20%22%20%2B%20y%20%2B%22%29%22%29%3B%0A%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20double%20calcularDistancia%28double%20x%2C%20double%20y%29%20%7B%0A%20%20%20%20%20%20%20%20double%20d%3B%0A%20%20%20%20%20%20%20%20d%20%3D%20Math.sqrt%28Math.pow%28this.x%20-%20x%2C%202%29%20%2B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20Math.pow%28this.y%20-%20y%2C%202%29%29%3B%0A%20%20%20%20%20%20%20%20return%20d%3B%20%20%0A%20%20%20%20%7D%0A%20%20%20%0A%20%20%20%20public%20double%20calcularDistancia%28Punto%20p%29%20%7B%0A%20%20%20%20%20%20%20%20double%20d%3B%0A%20%20%20%20%20%20%20%20d%20%3D%20Math.sqrt%28Math.pow%28this.x%20-%20p.x%2C%202%29%20%2B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20Math.pow%28this.y%20-%20p.y%2C%202%29%29%3B%0A%20%20%20%20%20%20%20%20return%20d%3B%0A%20%20%20%20%7D%0A%20%20%20%0A%7D%0A%0Apublic%20class%20PointDemo2%20%7B%0A%20%20%20%20public%20static%20void%20main%28String%5B%5D%20args%29%20%7B%0A%20%20%20%20%20%20%20%20/%2A%20Creando%204%20objetos%20tipo%20punto%20%2A/%0A%20%20%20%20%20%20%20%20final%20int%20NUMPUNTOS%20%3D%204%3B%0A%20%20%20%20%20%20%20%20Punto%5B%5D%20puntos%3B%0A%20%20%20%20%20%20%20%20puntos%20%3D%20new%20Punto%5BNUMPUNTOS%5D%3B%0A%20%20%20%20%20%20%20%20Punto%20A%20%3D%20new%20Punto%282%2C1%29%3B%0A%20%20%20%20%20%20%20%20Punto%20B%20%3D%20new%20Punto%28-3%2C4%29%3B%0A%20%20%20%20%20%20%20%20puntos%5B0%5D%20%3D%20A%3B%0A%20%20%20%20%20%20%20%20puntos%5B1%5D%20%3D%20B%3B%0A%20%20%20%20%20%20%20%20puntos%5B2%5D%20%3D%20new%20Punto%285%2C-6%29%3B%0A%20%20%20%20%20%20%20%20puntos%5B3%5D%20%3D%20new%20Punto%28-7%2C-8%29%3B%20%0A%20%20%20%20%20%20%20%20imprimirArray%28puntos%29%3B%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%7D%0A%20%20%20%20%0A%20%20%20%20public%20static%20void%20imprimirArray%28Punto%20%5B%5Dv%29%20%7B%0A%20%20%20%20%20%20%20%20for%28Punto%20e%3A%20v%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20e.imprimirCoordenadas%28%29%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%7D%0A&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=java&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>
